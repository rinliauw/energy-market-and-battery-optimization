# %%
import pandas as pd
import numpy as np

# %%
# define variables
BATTERY_CAPACITY = 580 # maximum capacity MWH
DISCHARGE_EFFICIENCY = 0.9
CHARGE_EFFICIENCY = 0.9
MARGINAL_LOSS_FACTOR = 0.991
MAX_CAPACITY = 300

# %%
# this function takes dataframe name as output of charge/discharge decision
# and preprocess it to match the generate capacity function
# assumes the csv files are in the same folder

def process_csv(df_name):
    df = pd.read_csv(df_name)
    # df = df.iloc[:,[1, 2, 4]] 'uncomment for label.csv'
    # df.columns = ['Time', 'Price', 'Status'] 'uncomment for label.csv'
    df['Status'].replace('Disharge', 'Discharge', inplace=True)
    df['Status'].replace(0, 'Do Nothing', inplace=True)
    df['Status'].replace(1, 'Charge', inplace=True)
    df['Status'].replace(-1, 'Discharge', inplace=True)
    df = df.dropna().reset_index(drop=True)
    return df

# %%
# generate_capacity calculates all the columns needed to calculate revenue
# and takes dataframe with columns ['Time', 'Price', 'Status'] as input

def generate_capacity(df):
    
    # initialises variable
    raw_power = 0
    opening_capacity = 0
    closing_capacity = 0
    market_dispatch = 0

    raw_power_s = pd.Series(dtype = float)
    opening_capacity_s = pd.Series(dtype = float)
    closing_capacity_s = pd.Series(dtype = float)
    market_dispatch_s = pd.Series(dtype = float)
    
    status = df['Status']
    for i in df.index:
        # print(i)
        if i == 0: # set opening capacity
            opening_capacity_s.loc[i] = 0
        else: # set opening capacity to previous closing capacity
            opening_capacity = closing_capacity_s.loc[i-1]
            opening_capacity_s.loc[i] = closing_capacity_s.loc[i-1]
        if status[i] == 'Charge':
            raw_power = -min(MAX_CAPACITY, ((int(BATTERY_CAPACITY) - float(opening_capacity_s[i]))/CHARGE_EFFICIENCY) * 2) # 300 is the minimum capacity
            market_dispatch = raw_power / 2
            closing_capacity = max(0, min(opening_capacity_s[i] - market_dispatch * CHARGE_EFFICIENCY, BATTERY_CAPACITY))
            raw_power_s.loc[i] = raw_power
            market_dispatch_s.loc[i] = market_dispatch
            closing_capacity_s.loc[i] = closing_capacity
        elif status[i] == 'Discharge':
            raw_power = min(MAX_CAPACITY, (float(opening_capacity_s[i]) * 2)) ##/ DISCHARGE_EFFICIENCY)
            market_dispatch = raw_power/2 * DISCHARGE_EFFICIENCY
            closing_capacity = max(0, min(opening_capacity_s[i] - (market_dispatch * 1/DISCHARGE_EFFICIENCY), BATTERY_CAPACITY))
            market_dispatch_s.loc[i] = market_dispatch
            closing_capacity_s.loc[i] = closing_capacity
            raw_power_s.loc[i] = raw_power
        else:
            raw_power_s.loc[i] = 0
            market_dispatch_s.loc[i] = 0
            closing_capacity_s.loc[i] = closing_capacity
    
    df['raw power'] = raw_power_s
    df['market dispatch'] = market_dispatch_s
    df['opening capacity'] = opening_capacity_s
    df['closing capacity'] = closing_capacity_s

# %%
# calculate_revenue calculates revenue from 2018-2021

def calculate_revenue(df):
    revenue_s = pd.Series(dtype = float)
    for i in df.index:
        if df['market dispatch'].loc[i] < 0:
            revenue_s.loc[i] = df['Price'].loc[i] * df['market dispatch'].loc[i] * (1 / MARGINAL_LOSS_FACTOR)
        else:
            revenue_s.loc[i] = df['Price'].loc[i] * df['market dispatch'].loc[i] * (MARGINAL_LOSS_FACTOR)
            
    df['revenue'] = revenue_s
    return sum(df['revenue'])

# %% [markdown]
# ## Calculate revenue from data
# -- for testing purposes only --

# %%
rev = process_csv('rev.csv')
rev
# Out:
#        Unnamed: 0                 Time  Price         MA     Status  Dispatch  \
# 0               5  2018-01-01 10:30:00  71.13  70.582571  Discharge    -150.0
# 1               6  2018-01-01 11:00:00  74.86  70.514571  Discharge    -150.0
# 2               7  2018-01-01 11:30:00  72.45  70.699429  Discharge    -150.0
# 3               8  2018-01-01 12:00:00  66.51  71.032571     Charge     135.0
# 4              10  2018-01-01 16:00:00  85.27  71.699714  Discharge     135.0
# ...           ...                  ...    ...        ...        ...       ...
# 28402       29968  2021-12-08 11:30:00  18.56  51.996000     Charge     135.0
# 28403       29969  2021-12-08 12:00:00  17.39  54.709143     Charge     135.0
# 28404       29970  2021-12-08 12:30:00   5.71  57.652000     Charge     135.0
# 28405       29971  2021-12-08 13:00:00   8.95  60.270571     Charge     135.0
# 28406       29972  2021-12-08 14:00:00  18.10  64.918857     Charge     135.0
#
#           _merge
# 0      left_only
# 1      left_only
# 2      left_only
# 3      left_only
# 4      left_only
# ...          ...
# 28402  left_only
# 28403  left_only
# 28404  left_only
# 28405  left_only
# 28406  left_only
#
# [28407 rows x 7 columns]

# %%
generate_capacity(rev)

# %%
calculate_revenue(rev)
# Out:
# 126377425.53897737

# %% [markdown]
# ### 1

# %%
zig10 = process_csv('zig10.csv')
zig10
# Out:
#        Unnamed: 0                 Time  Price      Status
# 0               0  2018-01-01 00:00:00  90.43  Do Nothing
# 1               1  2018-01-01 00:30:00  92.46  Do Nothing
# 2               2  2018-01-01 01:00:00  87.62  Do Nothing
# 3               3  2018-01-01 01:30:00  73.08  Do Nothing
# 4               4  2018-01-01 02:00:00  70.18  Do Nothing
# ...           ...                  ...    ...         ...
# 63452       63452  2021-08-14 22:00:00  49.93   Discharge
# 63453       63453  2021-08-14 22:30:00  62.86   Discharge
# 63454       63454  2021-08-14 23:00:00  32.26   Discharge
# 63455       63455  2021-08-14 23:30:00  25.10  Do Nothing
# 63456       63456  2021-08-15 00:00:00   8.73  Do Nothing
#
# [63457 rows x 4 columns]

# %%
generate_capacity(zig10)

# %%
calculate_revenue(zig10)

# %% [markdown]
# ### 2

# %%
zig5 = process_csv('zig5.csv')
zig5
# Out:
#        Unnamed: 0                 Time  Price      Status
# 0               0  2018-01-01 00:00:00  90.43  Do Nothing
# 1               1  2018-01-01 00:30:00  92.46  Do Nothing
# 2               2  2018-01-01 01:00:00  87.62  Do Nothing
# 3               3  2018-01-01 01:30:00  73.08  Do Nothing
# 4               4  2018-01-01 02:00:00  70.18      Charge
# ...           ...                  ...    ...         ...
# 63452       63452  2021-08-14 22:00:00  49.93   Discharge
# 63453       63453  2021-08-14 22:30:00  62.86   Discharge
# 63454       63454  2021-08-14 23:00:00  32.26   Discharge
# 63455       63455  2021-08-14 23:30:00  25.10   Discharge
# 63456       63456  2021-08-15 00:00:00   8.73  Do Nothing
#
# [63457 rows x 4 columns]

# %%
generate_capacity(zig5)

# %%
calculate_revenue(zig5)

# %% [markdown]
# ### 3

# %%
zigMA = process_csv('zigMA.csv')
zigMA
# Out:
#        Unnamed: 0                 Time  Price      Status
# 0               0  2018-01-01 00:00:00  90.43  Do Nothing
# 1               1  2018-01-01 00:30:00  92.46  Do Nothing
# 2               2  2018-01-01 01:00:00  87.62  Do Nothing
# 3               3  2018-01-01 01:30:00  73.08  Do Nothing
# 4               4  2018-01-01 02:00:00  70.18  Do Nothing
# ...           ...                  ...    ...         ...
# 63452       63452  2021-08-14 22:00:00  49.93  Do Nothing
# 63453       63453  2021-08-14 22:30:00  62.86  Do Nothing
# 63454       63454  2021-08-14 23:00:00  32.26  Do Nothing
# 63455       63455  2021-08-14 23:30:00  25.10  Do Nothing
# 63456       63456  2021-08-15 00:00:00   8.73  Do Nothing
#
# [63457 rows x 4 columns]

# %%
generate_capacity(zigMA)

# %%
calculate_revenue(zigMA)
# Out:
# 97421242.97958785

# %% [markdown]
# ### 4

# %%
label = process_csv('label.csv')
label.isna().sum() # check nan values
# Out:
# Time      0
# Price     0
# Status    0
# dtype: int64

# %%
generate_capacity(label)

# %%
calculate_revenue(label)
# Out:
# 24262216.062602937

# %% [markdown]
# ### 4.1 (sample data to check)

# %%
label_sample = label.iloc[0:30]
label_sample = label_sample.dropna().reset_index(drop=True)

# %%
generate_capacity(label_sample)

# %%
label_sample
# Out:
#                    Time  Price      Status   raw power  market dispatch  \
# 0   2018-01-01 00:00:00  90.43  Do Nothing    0.000000         0.000000
# 1   2018-01-01 00:30:00  92.46  Do Nothing    0.000000         0.000000
# 2   2018-01-01 01:00:00  87.62  Do Nothing    0.000000         0.000000
# 3   2018-01-01 01:30:00  73.08  Do Nothing    0.000000         0.000000
# 4   2018-01-01 02:00:00  70.18  Do Nothing    0.000000         0.000000
# 5   2018-01-01 02:30:00  67.43  Do Nothing    0.000000         0.000000
# 6   2018-01-01 03:00:00  66.31  Do Nothing    0.000000         0.000000
# 7   2018-01-01 03:30:00  67.72  Do Nothing    0.000000         0.000000
# 8   2018-01-01 04:00:00  65.50  Do Nothing    0.000000         0.000000
# 9   2018-01-01 04:30:00  64.50  Do Nothing    0.000000         0.000000
# 10  2018-01-01 05:00:00  65.41      Charge -300.000000      -150.000000
# 11  2018-01-01 05:30:00  63.66      Charge -300.000000      -150.000000
# 12  2018-01-01 06:00:00  59.90      Charge -300.000000      -150.000000
# 13  2018-01-01 06:30:00  64.67      Charge -300.000000      -150.000000
# 14  2018-01-01 07:00:00  66.89      Charge  -88.888889       -44.444444
# 15  2018-01-01 07:30:00  67.06   Discharge  300.000000       135.000000
# 16  2018-01-01 08:00:00  67.49   Discharge  300.000000       135.000000
# 17  2018-01-01 08:30:00  67.12   Discharge  300.000000       135.000000
# 18  2018-01-01 09:00:00  67.47   Discharge  288.888889       130.000000
# 19  2018-01-01 09:30:00  71.02   Discharge    0.000000         0.000000
# 20  2018-01-01 12:00:00  66.51      Charge -300.000000      -150.000000
# 21  2018-01-01 12:30:00  64.77      Charge -300.000000      -150.000000
# 22  2018-01-01 13:00:00  70.02      Charge -300.000000      -150.000000
# 23  2018-01-01 13:30:00  76.04      Charge -300.000000      -150.000000
# 24  2018-01-01 14:00:00  76.80      Charge  -88.888889       -44.444444
# 25  2018-01-01 14:30:00  76.77  Do Nothing    0.000000         0.000000
# 26  2018-01-01 15:00:00  73.21   Discharge  300.000000       135.000000
# 27  2018-01-01 15:30:00  78.59   Discharge  300.000000       135.000000
# 28  2018-01-01 16:00:00  85.27   Discharge  300.000000       135.000000
# 29  2018-01-01 16:30:00  80.80   Discharge  288.888889       130.000000
#
#     opening capacity  closing capacity       revenue
# 0                0.0               0.0      0.000000
# 1                0.0               0.0      0.000000
# 2                0.0               0.0      0.000000
# 3                0.0               0.0      0.000000
# 4                0.0               0.0      0.000000
# 5                0.0               0.0      0.000000
# 6                0.0               0.0      0.000000
# 7                0.0               0.0      0.000000
# 8                0.0               0.0      0.000000
# 9                0.0               0.0      0.000000
# 10               0.0             135.0  -9900.605449
# 11             135.0             270.0  -9635.721493
# 12             270.0             405.0  -9066.599395
# 13             405.0             540.0  -9788.597376
# 14             540.0             580.0  -2999.887880
# 15             580.0             430.0   8971.622100
# 16             430.0             280.0   9029.149650
# 17             280.0             130.0   8979.649200
# 18             130.0               0.0   8692.160100
# 19               0.0               0.0      0.000000
# 20               0.0             135.0 -10067.103935
# 21             135.0             270.0  -9803.733602
# 22             270.0             405.0 -10598.385469
# 23             405.0             540.0 -11509.586276
# 24             540.0             580.0  -3444.332324
# 25             580.0             580.0      0.000000
# 26             580.0             430.0   9794.399850
# 27             430.0             280.0  10514.163150
# 28             280.0             130.0  11407.846950
# 29             130.0               0.0  10409.464000

# %% [markdown]
# ## 5

# %%
count = process_csv('count.csv')
count.isna().sum() # check nan values
# Out:
# Time      0
# Price     0
# Status    0
# dtype: int64

# %%
count
# Out:
#                       Time  Price      Status
# 0      2018-01-01 00:00:00  90.43  Do Nothing
# 1      2018-01-01 00:30:00  92.46  Do Nothing
# 2      2018-01-01 01:00:00  87.62  Do Nothing
# 3      2018-01-01 01:30:00  73.08  Do Nothing
# 4      2018-01-01 02:00:00  70.18  Do Nothing
# ...                    ...    ...         ...
# 61291  2021-06-30 21:30:00  65.79      Charge
# 61292  2021-06-30 22:00:00  92.52      Charge
# 61293  2021-06-30 22:30:00  67.46      Charge
# 61294  2021-06-30 23:00:00  60.16  Do Nothing
# 61295  2021-06-30 23:30:00  73.85  Do Nothing
#
# [61296 rows x 3 columns]

# %%
generate_capacity(count)

# %%
calculate_revenue(count)
# Out:
# 17074123.446428295

# %% [markdown]
# ## 6

# %%
MA15 = process_csv('MA15-ZZ102.csv')
MA15
# Out:
#        Unnamed: 0                 Time   Price      Status
# 0               0  2018-01-01 00:00:00   90.43  Do Nothing
# 1               1  2018-01-01 00:30:00   92.46  Do Nothing
# 2               2  2018-01-01 01:00:00   87.62  Do Nothing
# 3               3  2018-01-01 01:30:00   73.08  Do Nothing
# 4               4  2018-01-01 02:00:00   70.18  Do Nothing
# ...           ...                  ...     ...         ...
# 63452       63452  2021-12-08 21:30:00   81.98  Do Nothing
# 63453       63453  2021-12-08 22:00:00   71.77  Do Nothing
# 63454       63454  2021-12-08 22:30:00  100.04  Do Nothing
# 63455       63455  2021-12-08 23:00:00   81.22  Do Nothing
# 63456       63456  2021-12-08 23:30:00   73.99  Do Nothing
#
# [63457 rows x 4 columns]

# %%
generate_capacity(MA15)

# %%
calculate_revenue(MA15)

# %% [markdown]
# ## 6

# %%
MA2017 = process_csv('check3rev.csv')
MA2017
# Out:
#                       Time   Price      Status
# 0      2018-01-01 00:00:00   90.43  Do Nothing
# 1      2018-01-01 00:30:00   92.46  Do Nothing
# 2      2018-01-01 01:00:00   87.62  Do Nothing
# 3      2018-01-01 01:30:00   73.08  Do Nothing
# 4      2018-01-01 02:00:00   70.18  Do Nothing
# ...                    ...     ...         ...
# 63452  2021-12-08 21:30:00   81.98  Do Nothing
# 63453  2021-12-08 22:00:00   71.77  Do Nothing
# 63454  2021-12-08 22:30:00  100.04  Do Nothing
# 63455  2021-12-08 23:00:00   81.22  Do Nothing
# 63456  2021-12-08 23:30:00   73.99  Do Nothing
#
# [63457 rows x 3 columns]

# %%
MA2017.to_csv('check3rev.csv')

# %%
MA2017
# Out:
#                       Time   Price      Status
# 0      2018-01-01 00:00:00   90.43  Do Nothing
# 1      2018-01-01 00:30:00   92.46  Do Nothing
# 2      2018-01-01 01:00:00   87.62  Do Nothing
# 3      2018-01-01 01:30:00   73.08  Do Nothing
# 4      2018-01-01 02:00:00   70.18  Do Nothing
# ...                    ...     ...         ...
# 63452  2021-12-08 21:30:00   81.98  Do Nothing
# 63453  2021-12-08 22:00:00   71.77  Do Nothing
# 63454  2021-12-08 22:30:00  100.04  Do Nothing
# 63455  2021-12-08 23:00:00   81.22  Do Nothing
# 63456  2021-12-08 23:30:00   73.99  Do Nothing
#
# [63457 rows x 3 columns]

# %%
MA2017_1 = MA2017.loc[(MA2017['Time'] >= '2020-07-17 00:30:00') & (MA2017['Time'] <= '2020-07-18 00:00:00')].reset_index(drop=True)

# %%
MA2017_1
# Out:
#                    Time   Price      Status
# 0   2020-07-17 00:30:00   75.51   Discharge
# 1   2020-07-17 01:00:00   73.98  Do Nothing
# 2   2020-07-17 01:30:00   75.57  Do Nothing
# 3   2020-07-17 02:00:00   71.94  Do Nothing
# 4   2020-07-17 02:30:00   74.10  Do Nothing
# 5   2020-07-17 03:00:00   67.36      Charge
# 6   2020-07-17 03:30:00   58.04      Charge
# 7   2020-07-17 04:00:00   51.85      Charge
# 8   2020-07-17 04:30:00   74.53      Charge
# 9   2020-07-17 05:00:00   67.32      Charge
# 10  2020-07-17 05:30:00   69.14  Do Nothing
# 11  2020-07-17 06:00:00   64.99  Do Nothing
# 12  2020-07-17 06:30:00   65.35  Do Nothing
# 13  2020-07-17 07:00:00   76.16  Do Nothing
# 14  2020-07-17 07:30:00   79.41   Discharge
# 15  2020-07-17 08:00:00   83.26   Discharge
# 16  2020-07-17 08:30:00  153.81   Discharge
# 17  2020-07-17 09:00:00   93.68   Discharge
# 18  2020-07-17 09:30:00   72.65      Charge
# 19  2020-07-17 10:00:00   71.66      Charge
# 20  2020-07-17 10:30:00  110.29   Discharge
# 21  2020-07-17 11:00:00   72.70   Discharge
# 22  2020-07-17 11:30:00   76.14  Do Nothing
# 23  2020-07-17 12:00:00   63.20      Charge
# 24  2020-07-17 12:30:00   71.71   Discharge
# 25  2020-07-17 13:00:00   67.72  Do Nothing
# 26  2020-07-17 13:30:00   46.23      Charge
# 27  2020-07-17 14:00:00   39.75      Charge
# 28  2020-07-17 14:30:00   39.94      Charge
# 29  2020-07-17 15:00:00   39.97      Charge
# 30  2020-07-17 15:30:00   42.72  Do Nothing
# 31  2020-07-17 16:00:00   55.85  Do Nothing
# 32  2020-07-17 16:30:00   66.67  Do Nothing
# 33  2020-07-17 17:00:00   71.83   Discharge
# 34  2020-07-17 17:30:00   73.94   Discharge
# 35  2020-07-17 18:00:00  163.47   Discharge
# 36  2020-07-17 18:30:00  137.10   Discharge
# 37  2020-07-17 19:00:00   73.85   Discharge
# 38  2020-07-17 19:30:00   72.12  Do Nothing
# 39  2020-07-17 20:00:00   67.65  Do Nothing
# 40  2020-07-17 20:30:00   73.96  Do Nothing
# 41  2020-07-17 21:00:00   59.97  Do Nothing
# 42  2020-07-17 21:30:00   58.53  Do Nothing
# 43  2020-07-17 22:00:00   57.89  Do Nothing
# 44  2020-07-17 22:30:00   56.54  Do Nothing
# 45  2020-07-17 23:00:00   48.70  Do Nothing
# 46  2020-07-17 23:30:00   49.60  Do Nothing
# 47  2020-07-18 00:00:00   52.77  Do Nothing

# %%
generate_capacity(MA2017_1)

# %%
calculate_revenue(MA2017_1)
# Out:
# 43355.217125731586

# %%
pd.set_option('display.max_rows', MA2017.shape[0]+1)

# %% [markdown]
# ## 7

# %%
MAdf_df2 = process_csv('MAdf_df2.csv')

# %%
MAdf_df2
# Out:
#         Unnamed: 0                 Time  Price      Status
# 0                0  2018-01-01 00:00:00  90.43  Do Nothing
# 1                1  2018-01-01 00:00:00  90.43  Do Nothing
# 2                2  2018-01-01 00:30:00  92.46  Do Nothing
# 3                3  2018-01-01 01:00:00  87.62  Do Nothing
# 4                4  2018-01-01 01:30:00  73.08  Do Nothing
# ...            ...                  ...    ...         ...
# 105697      105697  2021-08-14 22:30:00  62.86  Do Nothing
# 105698      105698  2021-08-14 22:30:00  62.86  Do Nothing
# 105699      105699  2021-08-14 23:00:00  32.26  Do Nothing
# 105700      105700  2021-08-14 23:30:00  25.10  Do Nothing
# 105701      105701  2021-08-15 00:00:00   8.73  Do Nothing
#
# [105702 rows x 4 columns]

# %%
generate_capacity(MAdf_df2)

# %%
calculate_revenue(MAdf_df2)
# Out:
# 93527563.81686416

# %% [markdown]
# ## 8

# %%
MAdf_df3 = process_csv('MAdf_df3.csv')

# %%
generate_capacity(MAdf_df3)

# %%
calculate_revenue(MAdf_df3)
# Out:
# 78730337.5804051

# %% [markdown]
# ## 9

# %%
final = process_csv('adrenaline.csv')

# %%
final
# Out:
#                       Time   Price      Status  Dispatch    mrf  Revenue
# 0      2018-01-01 00:00:00   90.43  Do Nothing       0.0  0.991      0.0
# 24 -300.000000      -150.000000               0.0             135.0
# 25 -300.000000      -150.000000             135.0             270.0
# 26 -300.000000      -150.000000             270.0             405.0
# 27  300.000000       135.000000             405.0             255.0
# 28  300.000000       135.000000             255.0             105.0
# 29  233.333333       105.000000             105.0               0.0
# 30    0.000000         0.000000               0.0               0.0
# 31    0.000000         0.000000               0.0               0.0
# 32 -300.000000      -150.000000               0.0             135.0
# 33  300.000000       135.000000             135.0               0.0
# 34 -300.000000      -150.000000               0.0             135.0
# 35  300.000000       135.000000             135.0               0.0
# 36    0.000000         0.000000               0.0               0.0
# 37    0.000000         0.000000               0.0               0.0
# 38    0.000000         0.000000               0.0               0.0
# 39 -300.000000      -150.000000               0.0             135.0
# 40 -300.000000      -150.000000             135.0             270.0
# 41 -300.000000      -150.000000             270.0             405.0
# 42 -300.000000      -150.000000             405.0             540.0
# 43  300.000000       135.000000             540.0             390.0
# 44  300.000000       135.000000             390.0             240.0
# 45 -300.000000      -150.000000             240.0             375.0
# 46 -300.000000      -150.000000             375.0             510.0
# 47 -155.555556       -77.777778             510.0             580.0
# 48   -0.000000        -0.000000             580.0             580.0
# 49   -0.000000        -0.000000             580.0             580.0
#
#          revenue
# 0       0.000000
# 1       0.000000
# 2       0.000000
# 3       0.000000
# 4       0.000000
# 5       0.000000
# 6       0.000000
# 7       0.000000
# 8       0.000000
# 9       0.000000
# 10      0.000000
# 11      0.000000
# 12      0.000000
# 13      0.000000
# 14      0.000000
# 15 -10150.353179
# 16 -10215.438951
# 17 -10159.434914
# 18 -10212.411705
# 19   9501.410700
# 20   9509.437800
# 21   9516.127050
# 22   6676.763400
# 23      0.000000
# 24 -10067.103935
# 25  -9803.733602
# 26 -10598.385469
# 27  10274.688000
# 28  10514.163150
# 29   8872.769850
# 30      0.000000
# 31      0.000000
# 32 -10409.182644
# 33   9450.572400
# 34 -10262.361251
# 35   9886.711500
# 36      0.000000
# 37      0.000000
# 38      0.000000
# 39  -9998.990918
# 40  -9803.733602
# 41  -9246.720484
# 42  -9619.071645
# 43  10033.875000
# 44   9343.544400
# 45  -7813.319879
# 46  -8291.624622
# 47  -4468.101805
# 48     -0.000000
# 49     -0.000000

# %% [markdown]
# ## 10

# %%
inter = process_csv('inter.csv')

# %%
inter
# Out:
#        Unnamed: 0                 Time   Price      Status
# 0               0  2018-01-01 00:00:00   90.43  Do Nothing
# 1               1  2018-01-01 00:30:00   92.46  Do Nothing
# 2               2  2018-01-01 01:00:00   87.62  Do Nothing
# 3               3  2018-01-01 01:30:00   73.08  Do Nothing
# 4               4  2018-01-01 02:00:00   70.18  Do Nothing
# ...           ...                  ...     ...         ...
# 63452       63452  2021-12-08 21:30:00   81.98  Do Nothing
# 63453       63453  2021-12-08 22:00:00   71.77  Do Nothing
# 63454       63454  2021-12-08 22:30:00  100.04  Do Nothing
# 63455       63455  2021-12-08 23:00:00   81.22  Do Nothing
# 63456       63456  2021-12-08 23:30:00   73.99  Do Nothing
#
# [63457 rows x 4 columns]

# %%
generate_capacity(inter)

# %%
calculate_revenue(inter)
# Out:
# 33347095.390472963

# %% [markdown]
# ## 11

# %%
inter = process_csv('Z.csv')

# 42  2018-01-01 21:00:00  70.04   Discharge      300.0            135.0
# 43  2018-01-01 21:30:00  71.25   Discharge        0.0              0.0
# 44  2018-01-01 22:00:00  66.06   Discharge        0.0              0.0
# 45  2018-01-01 22:30:00  64.77   Discharge        0.0              0.0
# 46  2018-01-01 23:00:00  61.09   Discharge        0.0              0.0
# 47  2018-01-01 23:30:00  63.55   Discharge        0.0              0.0
# 48  2018-01-02 00:00:00  75.00      Charge     -300.0           -150.0
# 49  2018-01-02 00:30:00  69.84   Discharge      300.0            135.0
#
#     opening capacity  closing capacity       revenue
# 0                0.0               0.0      0.000000
# 1                0.0               0.0      0.000000
# 2                0.0               0.0      0.000000
# 3                0.0               0.0      0.000000
# 4                0.0               0.0      0.000000
# 5                0.0               0.0      0.000000
# 6                0.0               0.0      0.000000
# 7                0.0               0.0      0.000000
# 8                0.0               0.0      0.000000
# 9                0.0               0.0      0.000000
# 10               0.0               0.0      0.000000
# 11               0.0               0.0      0.000000
# 12               0.0               0.0      0.000000
# 13               0.0               0.0      0.000000
# 14               0.0               0.0      0.000000
# 15               0.0               0.0      0.000000
# 16               0.0               0.0      0.000000
# 17               0.0               0.0      0.000000
# 18               0.0               0.0      0.000000
# 19               0.0               0.0      0.000000
# 20               0.0               0.0      0.000000
# 21               0.0               0.0      0.000000
# 22               0.0             135.0 -11330.978809
# 23             135.0               0.0   9692.723250
# 24               0.0               0.0      0.000000
# 25               0.0               0.0      0.000000
# 26               0.0               0.0      0.000000
# 27               0.0             135.0 -11509.586276
# 28             135.0               0.0  10274.688000
# 29               0.0               0.0      0.000000
# 30               0.0               0.0      0.000000
# 31               0.0               0.0      0.000000
# 32               0.0             135.0 -12906.659939
# 33             135.0               0.0  10809.828000
# 34               0.0               0.0      0.000000
# 35               0.0               0.0      0.000000
# 36               0.0               0.0      0.000000
# 37               0.0               0.0      0.000000
# 38               0.0               0.0      0.000000
# 39               0.0               0.0      0.000000
# 40               0.0               0.0      0.000000
# 41               0.0             135.0 -11801.715439
# 42             135.0               0.0   9370.301400
# 43               0.0               0.0      0.000000
# 44               0.0               0.0      0.000000
# 45               0.0               0.0      0.000000
# 46               0.0               0.0      0.000000
# 47               0.0               0.0      0.000000
# 48               0.0             135.0 -11352.169526
# 49             135.0               0.0   9343.544400

# %% [markdown]
# ## 12

# %%
old = process_csv('OldZ.csv')

# %%
generate_capacity(old)

# %%
calculate_revenue(old)
# Out:
# 46330853.385665014

# %%
a = pd.read_excel('Victoria_data.xlsx')

# %%
a.head(50)
# Out:
#          Time (UTC+10)  period  Regions VIC Trading Price ($/MWh)  \
# 0  2018-01-01 00:30:00       1                              92.46
# 1  2018-01-01 01:00:00       2                              87.62
# 2  2018-01-01 01:30:00       3                              73.08
# 3  2018-01-01 02:00:00       4                              70.18
# 4  2018-01-01 02:30:00       5                              67.43
# 5  2018-01-01 03:00:00       6                              66.31
# 6  2018-01-01 03:30:00       7                              67.72
# 7  2018-01-01 04:00:00       8                              65.50
# 8  2018-01-01 04:30:00       9                              64.50
# 9  2018-01-01 05:00:00      10                              65.41
# 10 2018-01-01 05:30:00      11                              63.66
# 11 2018-01-01 06:00:00      12                              59.90
# 12 2018-01-01 06:30:00      13                              64.67
# 13 2018-01-01 07:00:00      14                              66.89
# 14 2018-01-01 07:30:00      15                              67.06
# 15 2018-01-01 08:00:00      16                              67.49
# 16 2018-01-01 08:30:00      17                              67.12
# 17 2018-01-01 09:00:00      18                              67.47
# 18 2018-01-01 09:30:00      19                              71.02
# 19 2018-01-01 10:00:00      20                              71.08
# 20 2018-01-01 10:30:00      21                              71.13
# 21 2018-01-01 11:00:00      22                              74.86
# 22 2018-01-01 11:30:00      23                              72.45
# 23 2018-01-01 12:00:00      24                              66.51
# 24 2018-01-01 12:30:00      25                              64.77
# 25 2018-01-01 13:00:00      26                              70.02
# 26 2018-01-01 13:30:00      27                              76.04
# 27 2018-01-01 14:00:00      28                              76.80
# 28 2018-01-01 14:30:00      29                              76.77
# 29 2018-01-01 15:00:00      30                              73.21
# 30 2018-01-01 15:30:00      31                              78.59
# 31 2018-01-01 16:00:00      32                              85.27
# 32 2018-01-01 16:30:00      33                              80.80
# 33 2018-01-01 17:00:00      34                              81.76
# 34 2018-01-01 17:30:00      35                              75.14
# 35 2018-01-01 18:00:00      36                              73.45
# 36 2018-01-01 18:30:00      37                              68.77
# 37 2018-01-01 19:00:00      38                              70.64
# 38 2018-01-01 19:30:00      39                              67.80
# 39 2018-01-01 20:00:00      40                              73.90
# 40 2018-01-01 20:30:00      41                              77.97
# 41 2018-01-01 21:00:00      42                              70.04
# 42 2018-01-01 21:30:00      43                              71.25
# 43 2018-01-01 22:00:00      44                              66.06
# 44 2018-01-01 22:30:00      45                              64.77
# 45 2018-01-01 23:00:00      46                              61.09
# 46 2018-01-01 23:30:00      47                              63.55
# 47 2018-01-02 00:00:00      48                              60.31
# 48 2018-01-02 00:30:00       1                              57.33
# 49 2018-01-02 01:00:00       2                              56.32
#
#     Raw Power (MW)  Market Dispatch (MWh)  Opening Capacity (MWh)  \
# 0         0.000000               0.000000                       0
# 1         0.000000               0.000000                       0
# 2         0.000000               0.000000                       0
# 3         0.000000               0.000000                       0
# 4         0.000000               0.000000                       0
# 5         0.000000               0.000000                       0
# 6         0.000000               0.000000                       0
# 7         0.000000               0.000000                       0
# 8      -300.000000            -150.000000                       0
# 9         0.000000               0.000000                       0
# 10     -300.000000            -150.000000                     135
# 11     -300.000000            -150.000000                     270
# 12      -66.666667             -33.333333                     405
# 13        0.000000               0.000000                     435
# 14        0.000000               0.000000                     435
# 15        0.000000               0.000000                     435
# 16        0.000000               0.000000                     435
# 17        0.000000               0.000000                     435
# 18        0.000000               0.000000                     435
# 19        0.000000               0.000000                     435
# 20        0.000000               0.000000                     435
# 21        0.000000               0.000000                     435
# 22        0.000000               0.000000                     435
# 23        0.000000               0.000000                     435
# 24        0.000000               0.000000                     435
# 25        0.000000               0.000000                     435
# 26        0.000000               0.000000                     435
# 27        0.000000               0.000000                     435
# 28        0.000000               0.000000                     435
# 29        0.000000               0.000000                     435
# 30        0.000000               0.000000                     435
# 31      300.000000             135.000000                     435
# 32      300.000000             135.000000                     285
# 33      300.000000             135.000000                     135
# 34        0.000000               0.000000                       0
# 35        0.000000               0.000000                       0
# 36        0.000000               0.000000                       0
# 37        0.000000               0.000000                       0
# 38        0.000000               0.000000                       0
# 39        0.000000               0.000000                       0
# 40        0.000000               0.000000                       0
# 41        0.000000               0.000000                       0
# 42        0.000000               0.000000                       0
# 43        0.000000               0.000000                       0
# 44        0.000000               0.000000                       0
# 45        0.000000               0.000000                       0
# 46        0.000000               0.000000                       0
# 47        0.000000               0.000000                       0
# 48        0.000000               0.000000                       0
# 49        0.000000               0.000000                       0
#
#     Closing Capacity (MWh)       Revenue  Unnamed: 8 Unnamed: 9  Unnamed: 10
# 0                        0      0.000000         NaN     Period      Revenue
# 1                        0      0.000000         NaN   Training  1.19778e+08
# 2                        0      0.000000         NaN    Testing  5.78041e+06
# 3                        0      0.000000         NaN      Total  1.25558e+08
# 4                        0      0.000000         NaN        NaN          NaN
# 5                        0      0.000000         NaN        NaN          NaN
# 6                        0      0.000000         NaN        NaN          NaN
# 7                        0      0.000000         NaN        NaN          NaN
# 8                      135  -9762.865792         NaN        NaN          NaN
# 9                        0      0.000000         NaN        NaN          NaN
# 10                     270  -9635.721493         NaN        NaN          NaN
# 11                     405  -9066.599395         NaN        NaN          NaN
# 12                     435  -2175.243861         NaN        NaN          NaN
# 13                     435      0.000000         NaN        NaN          NaN
# 14                     435      0.000000         NaN        NaN          NaN
# 15                     435      0.000000         NaN        NaN          NaN
# 16                     435      0.000000         NaN        NaN          NaN
# 17                     435      0.000000         NaN        NaN          NaN
# 18                     435      0.000000         NaN        NaN          NaN
# 19                     435      0.000000         NaN        NaN          NaN
# 20                     435      0.000000         NaN        NaN          NaN
# 21                     435      0.000000         NaN        NaN          NaN
# 22                     435      0.000000         NaN        NaN          NaN
# 23                     435      0.000000         NaN        NaN          NaN
# 24                     435      0.000000         NaN        NaN          NaN
# 25                     435      0.000000         NaN        NaN          NaN
# 26                     435      0.000000         NaN        NaN          NaN
# 27                     435      0.000000         NaN        NaN          NaN
# 28                     435      0.000000         NaN        NaN          NaN
# 29                     435      0.000000         NaN        NaN          NaN
# 30                     435      0.000000         NaN        NaN          NaN
# 31                     285  11407.846950         NaN        NaN          NaN
# 32                     135  10809.828000         NaN        NaN          NaN
# 33                       0  10938.261600         NaN        NaN          NaN
# 34                       0      0.000000         NaN        NaN          NaN
# 35                       0      0.000000         NaN        NaN          NaN
# 36                       0      0.000000         NaN        NaN          NaN
# 37                       0      0.000000         NaN        NaN          NaN
# 38                       0      0.000000         NaN        NaN          NaN
# 39                       0      0.000000         NaN        NaN          NaN
# 40                       0      0.000000         NaN        NaN          NaN
# 41                       0      0.000000         NaN        NaN          NaN
# 42                       0      0.000000         NaN        NaN          NaN
# 43                       0      0.000000         NaN        NaN          NaN
# 44                       0      0.000000         NaN        NaN          NaN
# 45                       0      0.000000         NaN        NaN          NaN
# 46                       0      0.000000         NaN        NaN          NaN
# 47                       0      0.000000         NaN        NaN          NaN
# 48                       0      0.000000         NaN        NaN          NaN
# 49                       0      0.000000         NaN        NaN          NaN
